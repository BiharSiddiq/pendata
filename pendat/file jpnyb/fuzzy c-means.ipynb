# %%
# ⬇️ Install pustaka yang diperlukan (jika belum terinstal)
# !pip install -q pandas scikit-learn openpyxl

# 📁 Unggah file Excel
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4216b523-453b-4eb1-b9b5-41fbc823560d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4216b523-453b-4eb1-b9b5-41fbc823560d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 🧮 Import libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# 🔧 Fuzzy C-Means Algorithm
def fuzzy_c_means(X, n_clusters=2, m=2, max_iter=100, error=1e-5):
    n_samples = X.shape[0]
    U = np.random.dirichlet(np.ones(n_clusters), size=n_samples)

    for iteration in range(max_iter):
        U_old = U.copy()
        centers = np.dot(U.T ** m, X) / np.sum(U.T ** m, axis=1, keepdims=True)

        for i in range(n_samples):
            for j in range(n_clusters):
                denominator = sum(
                    (np.linalg.norm(X[i] - centers[j]) / np.linalg.norm(X[i] - centers[k])) ** (2 / (m - 1))
                    for k in range(n_clusters)
                )
                U[i, j] = 1 / denominator

        if np.linalg.norm(U - U_old) < error:
            break

    return centers, U

# %%
# 📊 Membaca file dan menjalankan FCM
# Ganti nama file jika berbeda
file_name = next(iter(uploaded))  # otomatis ambil nama file pertama
df = pd.read_excel(file_name, sheet_name='Lembar1')

# Normalisasi data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df)

# Jalankan Fuzzy C-Means (default: 2 klaster)
centers, membership = fuzzy_c_means(data_scaled, n_clusters=2)

# Gabungkan hasil ke DataFrame
membership_df = pd.DataFrame(membership, columns=[f'Cluster {i+1}' for i in range(membership.shape[1])])
result_df = pd.concat([df, membership_df], axis=1)

# Simpan hasil ke Excel
output_file = "hasil_fuzzy_c_means.xlsx"
result_df.to_excel(output_file, index=False)

# Tampilkan beberapa hasil
result_df.head()
# Out:
#    x1  x2  Cluster 1  Cluster 2
# 0   1   2   0.030059   0.969941
# 1   2   3   0.000057   0.999943
# 2   3   4   0.080769   0.919231
# 3   6   7   0.985581   0.014419
# 4   7   8   0.989757   0.010243

# %%
# Install pustaka yang dibutuhkan
# !pip install -q pandas scikit-learn openpyxl

# Upload file Excel
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-773a4258-eb68-46a1-a41b-7dc2b4bb7635" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-773a4258-eb68-46a1-a41b-7dc2b4bb7635">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import pustaka
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Definisi algoritma Fuzzy C-Means
def fuzzy_c_means(X, n_clusters=2, m=2, max_iter=100, error=1e-5):
    n_samples = X.shape[0]
    U = np.random.dirichlet(np.ones(n_clusters), size=n_samples)

    for iteration in range(max_iter):
        U_old = U.copy()
        centers = np.dot(U.T ** m, X) / np.sum(U.T ** m, axis=1, keepdims=True)

        for i in range(n_samples):
            for j in range(n_clusters):
                denominator = sum(
                    (np.linalg.norm(X[i] - centers[j]) / np.linalg.norm(X[i] - centers[k])) ** (2 / (m - 1))
                    for k in range(n_clusters)
                )
                U[i, j] = 1 / denominator

        if np.linalg.norm(U - U_old) < error:
            break

    return centers, U

# %%
# Baca nama file dari upload
file_name = next(iter(uploaded))

# Baca data dari Excel (pastikan sheet bernama 'Lembar1')
df = pd.read_excel(file_name, sheet_name='Lembar1')

# Normalisasi data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df)

# Jalankan Fuzzy C-Means
centers, membership = fuzzy_c_means(data_scaled, n_clusters=2)

# Tampilkan hasil pusat cluster
print("Pusat Cluster (dalam bentuk data ternormalisasi):")
for idx, center in enumerate(centers):
    print(f"Cluster {idx + 1}: {center}")
# Out:
# Pusat Cluster (dalam bentuk data ternormalisasi):
# Cluster 1: [0.91465179 0.91465179]
# Cluster 2: [0.16101718 0.16101718]
